# %% [markdown]
# # VacationPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# !pip install gmaps
# CELL 1:  
# NOTE: MUST HAVE api_keys file with weather api key AND config file with api key.  M Grad's api key files were included in .gitignore so they are not loaded to the repo in GitHub.
# Resolved by using "pip install python-gmaps" in command line
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import gmaps
import os
from pprint import pprint
import json

# Import API key
from api_keys import g_key

# %% [markdown]
# ### Store Part I results into DataFrame
# * Load the csv exported in Part I to a DataFrame

# %%
# CELL 2
# load output from Weather

# Store filepath in a variable
file_one = "../Output/weather_output.csv"

# DEBUG!! How to remove Unamed: 0 column
weather_df = pd.read_csv(file_one, encoding="ISO-8859-1")
weather_df
# Out:
#      Unnamed: 0                     City  Latitude  Longitude  Max Temp (C)  \
# 0             0                   albany     42.60     -73.97         33.33
# 1             1                    kapaa     22.08    -159.32         28.00
# 2             2                  ushuaia    -54.80     -68.30          0.00
# 3             3                     fare    -16.70    -151.02         25.37
# 4             4                   khasan     42.43     130.64         19.69
# ..          ...                      ...       ...        ...           ...
# 541         541                   beloha    -25.17      45.05         16.39
# 542         542                 billings     45.78    -108.50         26.11
# 543         543  puerto baquerizo moreno     -0.90     -89.60         23.00
# 544         544                    gazli     40.13      63.45         29.92
# 545         545               itacarambi    -15.10     -44.09         22.28
#
#      Humidity  Cloudiness  Wind Speed Country        Date
# 0          39          80        4.50      US  1595280523
# 1          74          90        5.70      US  1595280803
# 2          86           3        1.50      AR  1595280804
# 3          80          45       11.13      PF  1595281275
# 4          87          48        3.59      RU  1595281275
# ..        ...         ...         ...     ...         ...
# 541        74           0        5.75      MG  1595280843
# 542        34          40        5.70      US  1595281236
# 543        73          90        6.70      EC  1595281217
# 544        17           0        4.46      UZ  1595281350
# 545        55          35        1.98      BR  1595281350
#
# [546 rows x 10 columns]

# %% [markdown]
# ### Humidity Heatmap
# * Configure gmaps.
# * Use the Lat and Lng as locations and Humidity as the weight.
# * Add Heatmap layer to map.

# %%
# CELL 3
# Q: What does configure method do?
# DEBUG!! - why is map repeated 5x?

# Review activities from class

# Google developer API key
from config import gkey

# DEBUG!! module 'gmaps' has no attribute 'configure'
# Access maps with unique API key
gmaps.configure(api_key=gkey)


# Define locations
locations = weather_df[['Latitude', 'Longitude']]
humidity_df = weather_df["Humidity"]


# Plot Heatmap
fig = gmaps.figure()

# Create heat layer
heat_layer = gmaps.heatmap_layer(locations, weights=humidity_df, 
                                 dissipating=False, max_intensity=300,
                                 point_radius=5)


# Add layer
fig.add_layer(heat_layer)

# Display figure
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %% [markdown]
# ### Create new DataFrame fitting weather criteria
# * Narrow down the cities to fit weather conditions.
# * Drop any rows will null values.

# %%
# CELL 4
# DEBUG!! 

# What weather conditions e.g. >70 F (21.1 C) and < 80 F (26.6 C)
# Removed conditions
# (weather_df["Humidity"] > 30) & 
# (weather_df["Humidity"] < 70)
weather_cond_df = weather_df.loc[(weather_df["Max Temp (C)"] > 21.1) & (weather_df["Max Temp (C)"] < 26.6) &
                                 (weather_df["Wind Speed"] < 10) &
                                 (weather_df["Cloudiness"] == 0), :]

weather_cond_df
# Out:
#      Unnamed: 0               City  Latitude  Longitude  Max Temp (C)  \
# 9             9        san quintin     30.48    -115.95         24.26
# 122         122    arraial do cabo    -22.97     -42.03         24.00
# 165         165        chiesanuova     43.90      12.42         23.89
# 166         166         abu samrah     35.30      37.18         24.19
# 184         184             bastia     42.67       9.33         22.78
# 186         186          pringsewu     -5.36     104.97         22.43
# 228         228             tukrah     32.53      20.58         24.13
# 243         243          orbetello     42.44      11.22         24.00
# 272         272               surt     31.21      16.59         24.94
# 281         281              lodja     -3.48      23.43         22.61
# 282         282            termoli     41.99      14.99         22.64
# 291         291        palafrugell     41.92       3.16         23.89
# 317         317         nouadhibou     20.93     -17.03         26.00
# 324         324            shahrud     36.42      54.98         23.65
# 346         346            valreas     44.38       4.99         23.89
# 358         358           bardiyah     31.76      25.09         22.76
# 368         368            amuntai     -2.42     115.25         22.39
# 428         428            ajaccio     42.00       8.92         22.00
# 457         457               bafq     31.61      55.41         25.90
# 467         467  sao joao da barra    -21.64     -41.05         24.00
# 538         538       marsa matruh     31.35      27.25         25.00
#
#      Humidity  Cloudiness  Wind Speed Country        Date
# 9          54           0        9.85      MX  1595280676
# 122        83           0        5.70      BR  1595280805
# 165        68           0        1.00      SM  1595281296
# 166        46           0        3.96      SY  1595281297
# 184        83           0        1.50      FR  1595281299
# 186        92           0        0.43      ID  1595281299
# 228        72           0        6.40      LY  1595281306
# 243        69           0        1.50      IT  1595281309
# 272        76           0        5.07      LY  1595281313
# 281        45           0        0.73      CD  1595281315
# 282        51           0        2.42      IT  1595281315
# 291        50           0        4.49      ES  1595281105
# 317        69           0        1.50      MR  1595280751
# 324        28           0        2.98      IR  1595281320
# 346        83           0        3.60      FR  1595281323
# 358        85           0        5.46      LY  1595281325
# 368        97           0        0.51      ID  1595281327
# 428        73           0        3.10      FR  1595281335
# 457        17           0        3.08      IR  1595280843
# 467        73           0        5.10      BR  1595280845
# 538        78           0        2.10      EG  1595281350

# %% [markdown]
# ### Hotel Map
# * Store into variable named `hotel_df`.
# * Add a "Hotel Name" column to the DataFrame.
# * Set parameters to search for hotels with 5000 meters.
# * Hit the Google Places API for each city's coordinates.
# * Store the first Hotel result into the DataFrame.
# * Plot markers on top of the heatmap.

# %%
# CELL 5
# use class activities as a guide (Places API, Plot markers)
# USES GOOGLE PLACES API TO FIND HOTELS

# Find the nearest hotel to butaritari (lat: 3.07, lng: 172.79)

# geocoordinates
target_coordinates = "30.525279, -115.933061"
#target_search = "Chinese"
target_radius = 5000
target_type = "hotel"

# set up a parameters dictionary
# Removed from param:     "keyword": target_search,
params = {
    "location": target_coordinates,
    "radius": target_radius,
    "type": target_type,
    "key": gkey
}

# base url
base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"

# run a request using our params dictionary
response = requests.get(base_url, params=params).json()

pprint(response)
print(response["results"][0]["geometry"]["location"]["lat"])
print(response["results"][0]["geometry"]["location"]["lng"])
print(response["results"][0]["name"])
print(response["results"][0]["vicinity"])
# Out:
# {'html_attributions': [],
#  'next_page_token': 'CqQCGgEAAOpxrHsEYFEegrlO14j7-8Uf8XgEtIAJSb6nGK_4ClTuF8IATHh_xLwso3XCywI2EoQiEtFgLF0eP046gZJ9F3D4avXTOoVioUIGhGG2wFtOIGNDSrPbkEUxx5rgKD86PsCn2WGoZPtPLXzxYL_0lY-zCG0VQFgi0195__uk_2z_wOJOOv7f9BXepem_NN2QtiqP_tsRahFPNWG3Hmv9g4XfJoOTY9DYQ8rSkMSwrVq_wHIVMeM6Rg6_kyfUnmquNmUXMRMIZRbBrPaoQWwFh_G73dVere4DPCbaWIwAQxOyY4I4B53URNw-40Fu0OQgbcJjy6Ozk3F99UG8AAzx3wunZ-ITOu9SKsRWKM667lD5CLcxvT4ZF3sIwZRspiOJQhIQFIuAceeK1oLQSk2IbllACxoUWKAxwl3ryNU59L4h2hKUyXY9cXc',
#  'results': [{'geometry': {'location': {'lat': 30.5252789, 'lng': -115.9330606},
#                            'viewport': {'northeast': {'lat': 30.5532695,
#                                                       'lng': -115.9168024},
#                                         'southwest': {'lat': 30.5141821,
#                                                       'lng': -115.9553166}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/geocode-71.png',
#               'id': 'cce86bff4259124e24ee07e586bd5915380470f7',
#               'name': 'Lázaro Cárdenas',
#               'place_id': 'ChIJi1phurQPJoERBnWHGEuNAg8',
#               'reference': 'ChIJi1phurQPJoERBnWHGEuNAg8',
#               'scope': 'GOOGLE',
#               'types': ['locality', 'political'],
#               'vicinity': 'Lázaro Cárdenas'},
#              {'business_status': 'OPERATIONAL',
#               'geometry': {'location': {'lat': 30.52678799999999,
#                                         'lng': -115.931765},
#                            'viewport': {'northeast': {'lat': 30.5280392302915,
#                                                       'lng': -115.9303821697085},
#                                         'southwest': {'lat': 30.5253412697085,
#                                                       'lng': -115.9330801302915}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/gas_station-71.png',
#               'id': 'b2240d53db0f74c26e7fbd711bfb8ef9729197f0',
#               'name': 'Pemex',
#               'photos': [{'height': 3096,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/105721862953858654596">woman '
#                                                 ':3</a>'],
#                           'photo_reference': 'CmRaAAAAIibH02OjPvs6P2csgmyDrb72CL49-8FaeudWo8DUZeWcEn8FOT-Cqn08D3-x2fFxtBxh3rdU9nmCAJL-AGuhyAQks1BRkjQyjPjWRWstmBxrtTT485Vtehk1JNIkaRfzEhA3JL_uuc7GSZPEF91XLAB9GhSmGl_y7Wklm9dXOBFqzdh8yVzr8A',
#                           'width': 4128}],
#               'place_id': 'ChIJ_QZCgxsOJoERu5LjQjaFQcA',
#               'plus_code': {'compound_code': 'G3G9+P7 Lázaro Cárdenas, Baja '
#                                              'California, Mexico',
#                             'global_code': '8526G3G9+P7'},
#               'rating': 3.4,
#               'reference': 'ChIJ_QZCgxsOJoERu5LjQjaFQcA',
#               'scope': 'GOOGLE',
#               'types': ['gas_station', 'point_of_interest', 'establishment'],
#               'user_ratings_total': 26,
#               'vicinity': 'Carr.Transpeninsular Km.297 y Calle, Ingeniero Luis '
#                           'Alcerrega'},
#              {'business_status': 'OPERATIONAL',
#               'geometry': {'location': {'lat': 30.53855, 'lng': -115.93528},
#                            'viewport': {'northeast': {'lat': 30.5399205802915,
#                                                       'lng': -115.9338368697085},
#                                         'southwest': {'lat': 30.5372226197085,
#                                                       'lng': -115.9365348302915}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/gas_station-71.png',
#               'id': '631fc96a2652b3478c5d6cf0fda62b5660908e62',
#               'name': 'Pemex',
#               'photos': [{'height': 4608,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/105989407256963898522">Edward '
#                                                 'Everett Sr.</a>'],
#                           'photo_reference': 'CmRaAAAAiDVzgpvD9gaOYKcUaAAXr6gg51vbReqt2azsG8gXY7JICsXL6C67SsZfAWKAWoRrnTUOvvJ5FoU5nywogcYM6xyG8bqoBWjB-pQ4xfMEghLLrTky9XNOQmMXXlhrDMsdEhA1Sg3Vwhl_Hq6A2Gwvv6sWGhTyjn0WuMLo-GSxLT643CVHhjF8Vg',
#                           'width': 3456}],
#               'place_id': 'ChIJQerJTvsRJoERJhKVLPyAYCU',
#               'plus_code': {'compound_code': 'G3Q7+CV Lázaro Cárdenas, Baja '
#                                              'California, Mexico',
#                             'global_code': '8526G3Q7+CV'},
#               'rating': 3.3,
#               'reference': 'ChIJQerJTvsRJoERJhKVLPyAYCU',
#               'scope': 'GOOGLE',
#               'types': ['gas_station', 'point_of_interest', 'establishment'],
#               'user_ratings_total': 58,
#               'vicinity': 'Carrt. Transpeninsular Km 193 # 816, Ensenada'},
#              {'business_status': 'OPERATIONAL',
#               'geometry': {'location': {'lat': 30.51044, 'lng': -115.92655},
#                            'viewport': {'northeast': {'lat': 30.5118086802915,
#                                                       'lng': -115.9251154697085},
#                                         'southwest': {'lat': 30.5091107197085,
#                                                       'lng': -115.9278134302915}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/gas_station-71.png',
#               'id': 'c7397b390f10345eb74680d02cfc32a60a1baa55',
#               'name': 'Pemex',
#               'photos': [{'height': 1836,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/100715157861190021349">Ramon '
#                                                 'Arroyo</a>'],
#                           'photo_reference': 'CmRaAAAAgI-o6LY7IJYhS5evIRLJ83dafC_H3KUXRwzZEYHVoXqmxpyVXAYKYlgqaV3D8CxgXWIARxxj4WHolhU4wt27GCN6VZuT_D6wY4UtVUklUU3U_4WKW8o8JWuFRDYG76vnEhCj-8WmJI6Aqy8G7kU9tGx8GhQQ3jzQOV7ZCjlsC8L-EMmxrwUwSw',
#                           'width': 3264}],
#               'place_id': 'ChIJbyN2BmsOJoERwMhKbFC1aVc',
#               'plus_code': {'compound_code': 'G36F+59 Ejido Raúl Sánchez Díaz, '
#                                              'Baja California, Mexico',
#                             'global_code': '8526G36F+59'},
#               'rating': 3.6,
#               'reference': 'ChIJbyN2BmsOJoERwMhKbFC1aVc',
#               'scope': 'GOOGLE',
#               'types': ['gas_station', 'point_of_interest', 'establishment'],
#               'user_ratings_total': 40,
#               'vicinity': 'Carretera Transpeninsular No. 401, Ensenada'},
#              {'business_status': 'OPERATIONAL',
#               'geometry': {'location': {'lat': 30.56533, 'lng': -115.942966},
#                            'viewport': {'northeast': {'lat': 30.5666405802915,
#                                                       'lng': -115.9417650197085},
#                                         'southwest': {'lat': 30.5639426197085,
#                                                       'lng': -115.9444629802915}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/gas_station-71.png',
#               'id': '1f0005f34037c3f0041d312d1b400467cdac544a',
#               'name': 'Pemex',
#               'photos': [{'height': 502,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/101180871979039631259">Oscar '
#                                                 'Acosta</a>'],
#                           'photo_reference': 'CmRaAAAAxWRbSxzwoW7Vkq8FlTmPjc5Am9Jd2admOCSn8ZHkBG35wL60_EOHZ-g4Vezt5JWWweIwMNk6IbK4WQ8Flxf2T3C9G7gVtOBw4KwsKOMlmII7Y2tSxKtbTpSshuKovmpoEhDrbbl-aq5b2Ig3Ba68A4kxGhQmb13c2Y40jhIkLO53ptOZCh2E7A',
#                           'width': 1032}],
#               'place_id': 'ChIJq3e094YRJoERQ7fjiS_O0JU',
#               'plus_code': {'compound_code': 'H384+4R San Quintín, Baja '
#                                              'California, Mexico',
#                             'global_code': '8526H384+4R'},
#               'rating': 3.4,
#               'reference': 'ChIJq3e094YRJoERQ7fjiS_O0JU',
#               'scope': 'GOOGLE',
#               'types': ['gas_station', 'point_of_interest', 'establishment'],
#               'user_ratings_total': 120,
#               'vicinity': 'C.Primera Esq. Carr. Trnsp. Km.284'},
#              {'business_status': 'OPERATIONAL',
#               'geometry': {'location': {'lat': 30.535978, 'lng': -115.9384607},
#                            'viewport': {'northeast': {'lat': 30.5373124802915,
#                                                       'lng': -115.9371072697085},
#                                         'southwest': {'lat': 30.5346145197085,
#                                                       'lng': -115.9398052302915}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/generic_business-71.png',
#               'id': '6c9b4702daabfa93bed72acd00c71a6a55f6164f',
#               'name': 'Salud Digna para Todos I.A.P.',
#               'place_id': 'ChIJrVnTZPwRJoERuFuHcUKxefs',
#               'reference': 'ChIJrVnTZPwRJoERuFuHcUKxefs',
#               'scope': 'GOOGLE',
#               'types': ['health', 'point_of_interest', 'establishment'],
#               'vicinity': 'Lázaro Cárdenas 3000, Nuevo Mexicali, Lázaro '
#                           'Cárdenas'},
#              {'business_status': 'OPERATIONAL',
#               'geometry': {'location': {'lat': 30.5235176, 'lng': -115.9367421},
#                            'viewport': {'northeast': {'lat': 30.5248639302915,
#                                                       'lng': -115.9354044697085},
#                                         'southwest': {'lat': 30.5221659697085,
#                                                       'lng': -115.9381024302915}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/generic_business-71.png',
#               'id': '37fb050b283b78808b72c256a07edba778515649',
#               'name': 'Iusacell Telefonia Celular',
#               'place_id': 'ChIJK8xrHgUOJoERaANjaDPkANA',
#               'rating': 5,
#               'reference': 'ChIJK8xrHgUOJoERaANjaDPkANA',
#               'scope': 'GOOGLE',
#               'types': ['point_of_interest', 'establishment'],
#               'user_ratings_total': 1,
#               'vicinity': 'Boulevard Lázaro Cárdenas 2000, Nuevo Baja '
#                           'California, Plutarco Elías Calles'},
#              {'business_status': 'OPERATIONAL',
#               'geometry': {'location': {'lat': 30.5244179, 'lng': -115.9309939},
#                            'viewport': {'northeast': {'lat': 30.5257889802915,
#                                                       'lng': -115.9295505197085},
#                                         'southwest': {'lat': 30.5230910197085,
#                                                       'lng': -115.9322484802915}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/bank_dollar-71.png',
#               'id': '778bdf89988d91bd9241cdfa0fad993ac043a414',
#               'name': 'Telegrafos San Quintin',
#               'opening_hours': {'open_now': True},
#               'photos': [{'height': 573,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/118196672196197000551">rokema '
#                                                 'alor</a>'],
#                           'photo_reference': 'CmRaAAAACMI53P4Pm1TpW-sWXJBF9B8T26NIN1EMI8-Pk-W6HeBbE5A1BEjKWUJ5SpRpdfCNiYzYudjaGf632_rT7xDmNDSc8wBKd7PlrEYGXy7VlowXFfrNV-zfS2g9QQAHHJwjEhAUJ4q6EdWazaGXbiT4_Eq0GhQKwVDuGlHt4aDfJ8dZWTEAIXWUfg',
#                           'width': 749}],
#               'place_id': 'ChIJXxeoMhEOJoERFrE-Q9MeARU',
#               'plus_code': {'compound_code': 'G3F9+QJ San Quintín, Baja '
#                                              'California, Mexico',
#                             'global_code': '8526G3F9+QJ'},
#               'rating': 4.4,
#               'reference': 'ChIJXxeoMhEOJoERFrE-Q9MeARU',
#               'scope': 'GOOGLE',
#               'types': ['bank',
#                         'finance',
#                         'point_of_interest',
#                         'establishment'],
#               'user_ratings_total': 9,
#               'vicinity': 'Carretera Transpeninsular 170, San Quintín'},
#              {'business_status': 'OPERATIONAL',
#               'geometry': {'location': {'lat': 30.54474, 'lng': -115.937076},
#                            'viewport': {'northeast': {'lat': 30.54609538029149,
#                                                       'lng': -115.9356985197085},
#                                         'southwest': {'lat': 30.54339741970849,
#                                                       'lng': -115.9383964802915}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/doctor-71.png',
#               'id': 'bc4115fb4b5c93fdc905c6061bd1055402bc370e',
#               'name': 'IMSS Clínica 13 San Quintín',
#               'photos': [{'height': 1920,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/104697727793986706183">Marcos '
#                                                 'Torres</a>'],
#                           'photo_reference': 'CmRaAAAABvWrBsupoDC0LP4mpIUF-_HVDVlXdv1uwmYYma_El35jMPDpPILessvJA4B52JigcBT-IJwG_7h-yAnmpZLff_GEk4zCwFxLZl0UHqbm_XVLmy5eybknGk004pzOqmBpEhClk5J3580xILSAVBonApCeGhQB3WvletA4BHPLoiIpFjQI6gxWBQ',
#                           'width': 2560}],
#               'place_id': 'ChIJ5zK_TfARJoERXdEDtarlmJs',
#               'rating': 4.3,
#               'reference': 'ChIJ5zK_TfARJoERXdEDtarlmJs',
#               'scope': 'GOOGLE',
#               'types': ['hospital',
#                         'health',
#                         'point_of_interest',
#                         'establishment'],
#               'user_ratings_total': 6,
#               'vicinity': 'Carretera Transpeninsular Kilómetro 192, Ejido '
#                           'Nuevo Mexicali, San Quintín'},
#              {'business_status': 'OPERATIONAL',
#               'geometry': {'location': {'lat': 30.535978, 'lng': -115.9384607},
#                            'viewport': {'northeast': {'lat': 30.5373124802915,
#                                                       'lng': -115.9371072697085},
#                                         'southwest': {'lat': 30.5346145197085,
#                                                       'lng': -115.9398052302915}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/shopping-71.png',
#               'id': '4899fa0e982cef1198ce141d0a6f0318a5004175',
#               'name': 'Mr Refacciones',
#               'place_id': 'ChIJrVnTZPwRJoERxx2Lxeoua08',
#               'reference': 'ChIJrVnTZPwRJoERxx2Lxeoua08',
#               'scope': 'GOOGLE',
#               'types': ['car_repair',
#                         'point_of_interest',
#                         'store',
#                         'establishment'],
#               'vicinity': 'Calzada Lázaro Cárdenas 2800, Nuevo Mexicali, '
#                           'Lázaro Cárdenas'},
#              {'business_status': 'OPERATIONAL',
#               'geometry': {'location': {'lat': 30.5222599, 'lng': -115.9303629},
#                            'viewport': {'northeast': {'lat': 30.5236465302915,
#                                                       'lng': -115.9288549697085},
#                                         'southwest': {'lat': 30.5209485697085,
#                                                       'lng': -115.9315529302915}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/worship_general-71.png',
#               'id': '39bacc37b7df85272ce016592b64c7bc634f96ec',
#               'name': 'siloe',
#               'photos': [{'height': 960,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/118196672196197000551">rokema '
#                                                 'alor</a>'],
#                           'photo_reference': 'CmRaAAAA-Ar2Eb-m1-nk5QFgokxq_M_FiBprGIwBKddoEESM_vnXfpcBOoGUV0mzC_xR6Su3m7wZoN1_GGjNszfqs5C_pnlBEV_E2fpl9mlGHJB4KqrdKRghTUavGy1MpOkjDBjBEhDVg4EDqwP08ecacZunqbmmGhTI4FNNiX3aRx3N0XDOyU_pQrlq3A',
#                           'width': 1280}],
#               'place_id': 'ChIJDxh9oBAOJoERRtekd-vxCnk',
#               'plus_code': {'compound_code': 'G3C9+WV Lázaro Cárdenas, Baja '
#                                              'California, Mexico',
#                             'global_code': '8526G3C9+WV'},
#               'rating': 3.2,
#               'reference': 'ChIJDxh9oBAOJoERRtekd-vxCnk',
#               'scope': 'GOOGLE',
#               'types': ['church',
#                         'place_of_worship',
#                         'point_of_interest',
#                         'establishment'],
#               'user_ratings_total': 5,
#               'vicinity': 'Ensenada-Santa RosalÍa, Nuevo Baja California, '
#                           'Lázaro Cárdenas'},
#              {'business_status': 'OPERATIONAL',
#               'geometry': {'location': {'lat': 30.535978, 'lng': -115.9384607},
#                            'viewport': {'northeast': {'lat': 30.5373124802915,
#                                                       'lng': -115.9371072697085},
#                                         'southwest': {'lat': 30.5346145197085,
#                                                       'lng': -115.9398052302915}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/generic_business-71.png',
#               'id': '3de120489acf6628d6908d4f2d8ba52169897001',
#               'name': 'Salón Grecia',
#               'place_id': 'ChIJrVnTZPwRJoERz-kduFZVXyM',
#               'rating': 4.3,
#               'reference': 'ChIJrVnTZPwRJoERz-kduFZVXyM',
#               'scope': 'GOOGLE',
#               'types': ['point_of_interest', 'establishment'],
#               'user_ratings_total': 4,
#               'vicinity': 'Boulevard Lázaro Cárdenas 2842, Nuevo, Lázaro '
#                           'Cárdenas'},
#              {'business_status': 'OPERATIONAL',
#               'geometry': {'location': {'lat': 30.5086777, 'lng': -115.9254552},
#                            'viewport': {'northeast': {'lat': 30.5099891802915,
#                                                       'lng': -115.9242736697085},
#                                         'southwest': {'lat': 30.50729121970851,
#                                                       'lng': -115.9269716302915}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/police-71.png',
#               'id': '52a15818cd8d2e0b6843e54b57373674467afef4',
#               'name': 'Policia Federal Ensenada',
#               'photos': [{'height': 960,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/113011641005133196015">Paola '
#                                                 'Duron</a>'],
#                           'photo_reference': 'CmRaAAAA8wK01NCdHpoJ6soQWJoqfvSQvU7vERR9XqBCOKAMTke9Sj8elPkacK2Gu17zefq-IUIL_fJwUx-KiokL72aTPzuh0k5kYbdCNlz6jjcGBAabU5rWuzdU_xEXT4Wu_23OEhDQ6w9l7NwUlvqMwUvUJX1yGhTJvIhTlOJ36H7mBi3VrX8oIjjQcA',
#                           'width': 1280}],
#               'place_id': 'ChIJG-JDSGoOJoERFrne4TAAID0',
#               'plus_code': {'compound_code': 'G35F+FR Colonia Nueva Era, Baja '
#                                              'California, Mexico',
#                             'global_code': '8526G35F+FR'},
#               'rating': 2.5,
#               'reference': 'ChIJG-JDSGoOJoERFrne4TAAID0',
#               'scope': 'GOOGLE',
#               'types': ['police', 'point_of_interest', 'establishment'],
#               'user_ratings_total': 2,
#               'vicinity': 'Calle López Mateos 1360, Nueva Era, Colonia Nueva '
#                           'Era'},
#              {'business_status': 'OPERATIONAL',
#               'geometry': {'location': {'lat': 30.525355, 'lng': -115.931478},
#                            'viewport': {'northeast': {'lat': 30.5268028302915,
#                                                       'lng': -115.9301652697085},
#                                         'southwest': {'lat': 30.5241048697085,
#                                                       'lng': -115.9328632302915}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/doctor-71.png',
#               'id': '29e0ec2dc2320078d8154a50b89b56984f8d1e95',
#               'name': 'Bomberos San Quintin',
#               'photos': [{'height': 2576,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/101180871979039631259">Oscar '
#                                                 'Acosta</a>'],
#                           'photo_reference': 'CmRaAAAAk7Hy36op7wpTO6BEN7rNBiw3lz-WnZd9_IDgbjezBQgVI9NIp0RsU78fvUSZxePJUy72TqsnGGCAf5XfeswBE_ZhqLleuzLUfuDDuxFl2ScJn2HHs0el5SQtZ3R_Vn5CEhDyPgIexRihmskfPH8q0QGwGhQDo71FBKNDf6jdtlNZJaOdEvdhBQ',
#                           'width': 1932}],
#               'place_id': 'ChIJZ-R2rxsOJoER47Tv6iI6LMY',
#               'plus_code': {'compound_code': 'G3G9+4C Lázaro Cárdenas, Baja '
#                                              'California, Mexico',
#                             'global_code': '8526G3G9+4C'},
#               'rating': 5,
#               'reference': 'ChIJZ-R2rxsOJoER47Tv6iI6LMY',
#               'scope': 'GOOGLE',
#               'types': ['hospital',
#                         'health',
#                         'point_of_interest',
#                         'establishment'],
#               'user_ratings_total': 1,
#               'vicinity': 'Guerrero Negro - La Nueva Odisea 304, Lázaro '
#                           'Cárdenas'},
#              {'business_status': 'OPERATIONAL',
#               'geometry': {'location': {'lat': 30.5266218, 'lng': -115.9322416},
#                            'viewport': {'northeast': {'lat': 30.5278930802915,
#                                                       'lng': -115.9308657197085},
#                                         'southwest': {'lat': 30.5251951197085,
#                                                       'lng': -115.9335636802915}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/bank_dollar-71.png',
#               'id': '6fed81c4bbe0f9dead6b58b3a415c1cd860e5a4d',
#               'name': 'HSBC',
#               'opening_hours': {'open_now': True},
#               'photos': [{'height': 1080,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/113274230799760672554">Edgar '
#                                                 'Groove</a>'],
#                           'photo_reference': 'CmRaAAAAJPfuN0Sfo_MRggTeb-uLLVvlpnket8KBwmlETo6cvlEaLwoC-ZRt3LO95iSwdjh_jVVNCRyd22MPIABhFYPJ1e4ju_C3jhnkCWZtZXABQfz3SKMsXgGVZmbmhqHMeON4EhBkrIX2a8GT9yu1SK7vW2BUGhQte6zKF7p0MUsnBe4-B8-lRO844A',
#                           'width': 1920}],
#               'place_id': 'ChIJSQdCnhsOJoERn0RrDFk1yoE',
#               'plus_code': {'compound_code': 'G3G9+J4 Lázaro Cárdenas, Baja '
#                                              'California, Mexico',
#                             'global_code': '8526G3G9+J4'},
#               'rating': 2.1,
#               'reference': 'ChIJSQdCnhsOJoERn0RrDFk1yoE',
#               'scope': 'GOOGLE',
#               'types': ['bank',
#                         'atm',
#                         'finance',
#                         'point_of_interest',
#                         'establishment'],
#               'user_ratings_total': 11,
#               'vicinity': 'Lázaro Cárdenas 22940, Nuevo Baja California, '
#                           'Lázaro Cárdenas'},
#              {'business_status': 'OPERATIONAL',
#               'geometry': {'location': {'lat': 30.5260918, 'lng': -115.9309394},
#                            'viewport': {'northeast': {'lat': 30.5274174802915,
#                                                       'lng': -115.9296842197085},
#                                         'southwest': {'lat': 30.5247195197085,
#                                                       'lng': -115.9323821802915}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/generic_business-71.png',
#               'id': '5e98151a9e608170db970128c6bc84bee7ccdf9a',
#               'name': 'PEDIATRA Y DENTISTA PARA NIÑOS',
#               'photos': [{'height': 1360,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/112249957494562715995">Liliana '
#                                                 'Bernal</a>'],
#                           'photo_reference': 'CmRaAAAA7nnJh5opxCCwbGt6ZZi0YfXxcWsaBeVf9Gwxs3MYYfpVU-a0VacYgnJCPVJeTzdHyxPgU9qcJfUP8gAiIobO6zcefgPlD1btOkaFYbUsu4eVPtJapw9WODO12luYFtlfEhDh0Lczcx9a4xGEKtc_mg7QGhSV-CfmHaKW-JUfpLdNswySKvB_tA',
#                           'width': 2048}],
#               'place_id': 'ChIJNTbmvRsOJoERjiuErgpPlPg',
#               'plus_code': {'compound_code': 'G3G9+CJ Ampliación Nuevo Baja '
#                                              'California ( Ampliación Lázaro '
#                                              'Cárdenas), Lázaro Cárdenas, Baja '
#                                              'California, Mexico',
#                             'global_code': '8526G3G9+CJ'},
#               'rating': 4.5,
#               'reference': 'ChIJNTbmvRsOJoERjiuErgpPlPg',
#               'scope': 'GOOGLE',
#               'types': ['doctor',
#                         'health',
#                         'point_of_interest',
#                         'establishment'],
#               'user_ratings_total': 2,
#               'vicinity': '308,, Carretera Federal 1, Ampliación Nuevo Baja '
#                           'California ( Ampliación Lázaro Cárdenas)'},
#              {'business_status': 'OPERATIONAL',
#               'geometry': {'location': {'lat': 30.5277388, 'lng': -115.9331642},
#                            'viewport': {'northeast': {'lat': 30.5290972302915,
#                                                       'lng': -115.9317736697085},
#                                         'southwest': {'lat': 30.5263992697085,
#                                                       'lng': -115.9344716302915}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/generic_recreational-71.png',
#               'id': '3b91f19b2a91d054dc0ff03f3149ceb6052462b3',
#               'name': 'San Quintín Botanical Garden',
#               'opening_hours': {'open_now': True},
#               'photos': [{'height': 3648,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/109537751498973278119">Jardín '
#                                                 'Botánico San Quintín</a>'],
#                           'photo_reference': 'CmRaAAAAeXgYZg7KRxQNZqkyg581R2khecefpSiTobTQZGHVbwvv62uxMSBIP48NQ0SKJwKeccp2zv__P98OsAmwF3V3N6oZqHPeCW0fBx18ojPkj8GarYvyWJBFVJEkL9nz471nEhCN83oxPWUmsTv6w1N1KHKoGhT0RAN4CEF8fBUROLxEsEzPYMva1Q',
#                           'width': 5472}],
#               'place_id': 'ChIJMaRXlxwOJoERlMPR0il5_cQ',
#               'plus_code': {'compound_code': 'G3H8+3P Lázaro Cárdenas, Baja '
#                                              'California, Mexico',
#                             'global_code': '8526G3H8+3P'},
#               'rating': 4.4,
#               'reference': 'ChIJMaRXlxwOJoERlMPR0il5_cQ',
#               'scope': 'GOOGLE',
#               'types': ['tourist_attraction',
#                         'park',
#                         'point_of_interest',
#                         'establishment'],
#               'user_ratings_total': 121,
#               'vicinity': 'General Esteban Cantú 200, Nuevo Baja California, '
#                           'Lázaro Cárdenas'},
#              {'business_status': 'OPERATIONAL',
#               'geometry': {'location': {'lat': 30.5276465, 'lng': -115.9316189},
#                            'viewport': {'northeast': {'lat': 30.52898738029149,
#                                                       'lng': -115.9303052697085},
#                                         'southwest': {'lat': 30.52628941970849,
#                                                       'lng': -115.9330032302915}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/generic_business-71.png',
#               'id': '5e149ac4442ce85599df542ce145e854a13a7536',
#               'name': 'Computadoras y Celulares M & M',
#               'place_id': 'ChIJhYrKA7xfNIERFRn9ugDUizk',
#               'plus_code': {'compound_code': 'G3H9+39 San Quintín, Baja '
#                                              'California, Mexico',
#                             'global_code': '8526G3H9+39'},
#               'reference': 'ChIJhYrKA7xfNIERFRn9ugDUizk',
#               'scope': 'GOOGLE',
#               'types': ['point_of_interest', 'establishment'],
#               'vicinity': 'Carretera Transpeninsular 209, San Quintín'},
#              {'business_status': 'OPERATIONAL',
#               'geometry': {'location': {'lat': 30.5243937, 'lng': -115.9299778},
#                            'viewport': {'northeast': {'lat': 30.52579598029151,
#                                                       'lng': -115.9283897197085},
#                                         'southwest': {'lat': 30.52309801970851,
#                                                       'lng': -115.9310876802915}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/shopping-71.png',
#               'id': '58164bc22e7ef16da6e44561c836e7acaf512fa7',
#               'name': 'Interface Reparacion',
#               'opening_hours': {'open_now': True},
#               'photos': [{'height': 2988,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/100204143234914171364">Victor '
#                                                 'Antonio Medina Gutierrez</a>'],
#                           'photo_reference': 'CmRaAAAA2XLFSXpe6gPhv-C8_eQIYRrt-ZpaMBJPsu0g5Dj4jR4X926YhYpHoD5-zzB2XkBY0y8JfevOmNeD9wJCcz6dEaBxP9NwfUWLQhpOwB0QkumaagbE-BUaCHhBAhTTnEAVEhB7aQ3tYbkvwSDOyax7_hbzGhQRuTR3F4UGHO38sO_8hzBFM421Iw',
#                           'width': 5312}],
#               'place_id': 'ChIJNyh-MBoOJoERgQVbWyXUr4A',
#               'plus_code': {'compound_code': 'G3FC+Q2 Lázaro Cárdenas, Baja '
#                                              'California, Mexico',
#                             'global_code': '8526G3FC+Q2'},
#               'rating': 4.3,
#               'reference': 'ChIJNyh-MBoOJoERgQVbWyXUr4A',
#               'scope': 'GOOGLE',
#               'types': ['point_of_interest', 'store', 'establishment'],
#               'user_ratings_total': 3,
#               'vicinity': 'Guerrero Negro - La Nueva Odisea 418, Lázaro '
#                           'Cárdenas'},
#              {'geometry': {'location': {'lat': 30.5460607, 'lng': -115.9320171},
#                            'viewport': {'northeast': {'lat': 30.5532695,
#                                                       'lng': -115.9213638},
#                                         'southwest': {'lat': 30.5332415,
#                                                       'lng': -115.9441041}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/geocode-71.png',
#               'id': '40437ee6e4d18b239db64b93af71147c5f7bd8b2',
#               'name': 'Nuevo Mexicali',
#               'place_id': 'ChIJhcqi7-URJoERlcvwl7_bFko',
#               'reference': 'ChIJhcqi7-URJoERlcvwl7_bFko',
#               'scope': 'GOOGLE',
#               'types': ['sublocality_level_1', 'sublocality', 'political'],
#               'vicinity': 'Nuevo Mexicali'}],
#  'status': 'OK'}
# 30.5252789
# -115.9330606
# Lázaro Cárdenas
# Lázaro Cárdenas

# %%
# CELL 6
# Find the nearest hotel to each location in weather_cond_df


# Search criteria
target_radius = 5000
target_type = "hotel"

# base url
base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"

# create empty lists for lat, lng, hotel name, viscinity
hotel_dict = {"Lat": [],
             "Lng": [],
             "Hotel Name": [],
             "Vicinity": [],
             "Country": []}

coord_list = []
hotel_df = pd.DataFrame(hotel_dict)

hotel_lat = []
hotel_lng = []
hotel_name = []
hotel_vicinity = []
hotel_address = []

# DEBUG!! redo iloc to return only lat lng
for i, row in weather_cond_df.iterrows():  
    
    # geocoordinates
    #target_coordinates = weather_cond_df.iloc[i, 2:4]
    target_coordinates = f"{row['Latitude']}, {row['Longitude']}"
    #print(target_coordinates)
    
    # DEBUG!! appneding as string instead of tuple
    # append coord_list with tuple of lat, lng
    #lat_lng_pair = f"({row['Latitude']}, {row['Longitude']})"
    
    # - NEED EXTRA ():  coord_list.append(tuple(row['Latitude'], row['Longitude']))
    coord_list.append(tuple((row['Latitude'], row['Longitude'])))
    locations = weather_cond_df[["Latitude", "Longitude"]]
    
    # set up a parameters dictionary
    # Removed from param:     "keyword": target_search,

    params = {
        "location": target_coordinates,
        "radius": target_radius,
        "type": target_type,
        "key": gkey
    }

    # run a request using our params dictionary
   
    response = requests.get(base_url, params=params).json()
    #pprint(response)
    
    # store response in hotel_df
    # DEBUG!! Verify this structure works
    hotel_lat.append(response["results"][1]["geometry"]["location"]["lat"])
    hotel_lng.append(response["results"][1]["geometry"]["location"]["lng"])
    hotel_name.append(response["results"][1]["name"])
    hotel_vicinity.append(response["results"][1]["vicinity"])
    hotel_address.append(response["results"][1]["plus_code"]["compound_code"])
    
    
hotel_df["Lat"] = hotel_lat
hotel_df["Lng"] = hotel_lng
hotel_df["Hotel Name"] = hotel_name
hotel_df["Vicinity"] = hotel_vicinity
hotel_df["City"] = hotel_address

# Lookup overloading
country_code = list(weather_cond_df["Country"].reset_index(drop=True))
country_code
# DEBUG!! Visinity and Country NaN
# DEBUG!! How to get country from hotel api data
# df[['First','Last']] = df.Name.str.split("_",expand=True)
hotel_df["Country"] = country_code
hotel_df
# Out:
#           Lat         Lng                             Hotel Name  \
# 0   30.510440 -115.926550                                  Pemex
# 1  -22.977949  -42.023863                    Pousada Porto Praia
# 2   43.926781   12.450697                          Hotel Silvana
# 3   35.322916   37.199224             Parseckopen.tk Datacentrum
# 4   42.682778    9.305556                      Hotel Santa Maria
# 5   -5.354551  104.979960              Puspa Jaya Agen Pringsewu
# 6   32.528266   20.598312                        استراحة لاقروتا
# 7   42.416807   11.184924           Argentario Golf Resort & Spa
# 8   31.206956   16.579152                          Sirte Central
# 9   -3.489584   23.427912  Lodja, Republica Democrática do Congo
# 10  42.004176   14.991499                          Hotel Mistral
# 11  41.887538    3.178407                            Hotel Garbi
# 12  20.912917  -17.027760                              El Medina
# 13  36.427303   54.967664                      Refah Chain Store
# 14  44.379722    5.007222                        Maison d'Anvers
# 15  31.753456   25.101152                              وادي شماس
# 16  -2.419823  115.257867                  Pegadaian UPC Amuntai
# 17  41.988545    8.909264                           Sole E Monte
# 18  31.592255   55.398760           Hazrat-e- Vali-ye-asr Mosque
# 19 -21.634682  -41.048224                   AC São João da Barra
# 20  31.368336   27.222147                            lover Beach
#
#                                              Vicinity Country  \
# 0         Carretera Transpeninsular No. 401, Ensenada      MX
# 1    Rua Vilas Bôas, 161 - Macedônia, Arraial do Cabo      BR
# 2            Via del Serrone, 15, Città di San Marino      SM
# 3                                               Suruj      SY
# 4                  Lieu dit Cisternino, Saint-Florent      FR
# 5   Terminal Pringsewu, Jl. Pemuda No.53, Pringsew...      ID
# 6               توكرة الطريق السريع مقابل محطة الوقود      LY
# 7             Via Acquedotto Leopoldino, Porto Ercole      IT
# 8                                               Sirte      LY
# 9                                               Lodja      CD
# 10                Via Cristoforo Colombo, 50, Termoli      IT
# 11  Avinguda de Baldomer Gili i Roig, 20, Calella ...      ES
# 12     zone dubai ext.p5 lot 72. BP. 4350, Nouadhibou      MR
# 13                          Shahroud, Ferdowsi Street      IR
# 14                   71 Chemin des Anthelmes, Valréas      FR
# 15                                              Libya      LY
# 16                  Jalan Abdul Azis No.131, Antasari      ID
# 17                 Sole e Monte, Cuttoli-Corticchiato      FR
# 18                                              Bafgh      IR
# 19  Rua do Sacramento, 116 - Centro, São João da B...      BR
# 20                                       Mersa Matruh      EG
#
#                                                  City
# 0   G36F+59 Ejido Raúl Sánchez Díaz, Baja Californ...
# 1   2XCG+RF Macedônia, Arraial do Cabo - State of ...
# 2                                  WFG2+P7 San Marino
# 3                                85FX+5M Suruj, Syria
# 4                       M8M4+46 Saint-Florent, France
# 5   JXWH+5X North Pringsewu, Pringsewu Regency, La...
# 6                                GHHX+88 Tocra, Libya
# 7   C58M+PX Porto Ercole, Province of Grosseto, Italy
# 8                                6H4H+QM Sirte, Libya
# 9     GC6H+55 Lodja, Democratic Republic of the Congo
# 10     2X3R+MH Termoli, Province of Campobasso, Italy
# 11              V5QH+29 Calella de Palafrugell, Spain
# 12                     WX7C+5V Nouadhibou, Mauritania
# 13            CXG9+W3 Shahroud, Semnan Province, Iran
# 14                            92H4+VV Valréas, France
# 15                            Q432+9F Bardiyah, Libya
# 16  H7J5+34 Antasari, North Hulu Sungai Regency, S...
# 17               XWQ5+CP Cuttoli-Corticchiato, France
# 18                 H9RX+WG Bafgh, Yazd Province, Iran
# 19  9X82+4P Centro, São João da Barra - State of R...
# 20          969C+8V Marsa Matruh, Mersa Matruh, Egypt

# %%
# Cell 6.5
# split city into multiple columns to extract city and country
#

# %%
# CELL 7
# NOTE: Do not change any of the code in this cell

# Using the template add the hotel marks to the heatmap
info_box_template = """
<dl>
<dt>Name</dt><dd>{Hotel Name}</dd>
<dt>City</dt><dd>{City}</dd>
<dt>Country</dt><dd>{Country}</dd>
</dl>
"""
# Store the DataFrame Row
# NOTE: be sure to update with your DataFrame name
hotel_info = [info_box_template.format(**row) for index, row in hotel_df.iterrows()]
locations = hotel_df[["Lat", "Lng"]]
#locations

# %%
coord_list
type(coord_list[0])
# Out:
# tuple

# %%
# CELL 8
# How to do???
# Add marker layer ontop of heat map


# Assign the marker layer to a variable
# DEBUG!!  Error: ValueError: too many values to unpack (expected 2)
markers = gmaps.marker_layer(locations, info_box_content=hotel_info)

# Add the layer to the map
fig.add_layer(markers)

# Display figure
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))
